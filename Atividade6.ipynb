# %% [markdown]
# Nome: Sandra Rojas Zegarrundo  GU3030768
#
# Atividade 6

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# 1. Faça um histograma da coluna tips
sns.histplot(tips['tip'], kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# 2. Faça um boxplot da coluna total_bill
sns.boxplot(y='total_bill', data=tips)
# Out:
# <Axes: ylabel='total_bill'>

# %%
# 3. Faça um boxplot usando as variáveis tips e time
sns.boxplot(x='time', y='tip', data=tips)
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
# 4. Faça um violinplot usando as variáveis tips e smoker
sns.violinplot(x='smoker', y='tip', data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>
